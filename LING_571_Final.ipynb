# %% [markdown]
# <a href="https://colab.research.google.com/github/joseliine/LING571-FinalProject/blob/main/LING_571_Final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **1. Open episode files**

# %%
spanglish1 = "/content/spanglish_ep1.txt"
file1 = open(spanglish1, "r")
ep1 = file1.read()
ep1
# Out:
# 'Hi me llamo Cindy and I am the host of Do you Spanglish? This podcast is not an informational or an educational podcast this is simply a fun and lighthearted podcast where most of us latinos can relate. I am half Mexican half Salvadorian but I was born and raised in Los Angeles Hollywood to be exact. I remember growing up in a household where my parents enforced the Spanish language but my sister and I spoken English the entire time at school. So you see how my brain can easily mix and match the two languages. Mis amigos tease me because I pretty much speak Spanglish most of the time so Im glad que no soy la unica. Stay tuned for the laughs the memories the chiste and the chisme as I catch up with others who also live their lives in two languages. Stay tuned!'

# %%
spanglish2 = "/content/spanglish_ep2.txt"
file2 = open(spanglish2, "r")
episode2_raw = file2.read()
episode2_raw
# Out:
# 'Alright today I am here with Melissa and welcome everybody to do you spanglish? \num.. \nTodays topic is the S word\n\nThe s word. Whats the s word Cindy? Are we talking about sex? What exactly are we talking about here cuz you said that this was gunna be fun and not embarrassing \n\nSpanish! \n\nOkay yay\n\nEl español. Um..so basically I just wanna talk about Spanish because I am a Latino who was born and raised in Los Angeles Hollywood literally in the in the heart of Hollywood. so I remember growing up and always being embarrassed like in Middle School and even in high school. Being embarrassed of just speaking Spanish around my friends if my parents came around and spoke to me in Spanish I was like ugh and I would answer in English and id be like mom like dad please like english you need to learn English...um...and you know they were always enforcing the Spanish language in the household and they were like aqui solo se habla espanol if youre living under my roof vas a hablar esp
# ...

# %% [markdown]
# remove line breaks \n\

# %%
ep2 = episode2_raw.rstrip("\n")
print(ep2)
# Out:
# Alright today I am here with Melissa and welcome everybody to do you spanglish?
# um..
# Todays topic is the S word
#
# The s word. Whats the s word Cindy? Are we talking about sex? What exactly are we talking about here cuz you said that this was gunna be fun and not embarrassing
#
# Spanish!
#
# Okay yay
#
# ...

# %%
spanglish3 = "/content/spanglish_ep3.txt"
file3 = open(spanglish3, "r")
episode3_raw = file3.read()
episode3_raw
# Out:
# 'all right everyone and welcome to do you Spanglish? today I have my friend Geneva here with me\n\nhi \n\nthank you so much for joining me \n\nthank you\n\num todays topic is gunna be is your life over when you have a baby? uh so you know many of you dont know my friend Geneva so please introduce yourself and you know how long weve known each other and tell us you know your experience as a mother shes a mother now um after what three years of being a mother so I just want to kind of like pick your brain as to like life after you know after you become a mother\n\nyeah, okay, well first of all thank you for having me\n\nof course\n\nsuper excited \n\noh my gosh \n\nUh so yeah like Cindy said Im a mom my daughter is going to be three in a few days now oh my gosh I cant believe that. Ay dios mio!\n\nit feels like she literally was just born yesterday\n\nyeah\n\nlike it feels like it was just yesterday I went to the hospital to see you\n\nOh my god I know\n\nAnd here we are almost four ye
# ...

# %%
ep3 = episode3_raw.rstrip("\n")
print(ep3)

# %% [markdown]
# **2. Normalize all words**

# %%
import nltk
nltk.download('punkt')
nltk.download('wordnet')
from nltk import word_tokenize
from nltk.tokenize import RegexpTokenizer

# %%
episode1 = ep1
words = nltk.word_tokenize(ep1)
words_ep1 =[word.lower() for word in words if word.isalpha()]
print(words_ep1)
# Out:
# ['hi', 'me', 'llamo', 'cindy', 'and', 'i', 'am', 'the', 'host', 'of', 'do', 'you', 'spanglish', 'this', 'podcast', 'is', 'not', 'an', 'informational', 'or', 'an', 'educational', 'podcast', 'this', 'is', 'simply', 'a', 'fun', 'and', 'lighthearted', 'podcast', 'where', 'most', 'of', 'us', 'latinos', 'can', 'relate', 'i', 'am', 'half', 'mexican', 'half', 'salvadorian', 'but', 'i', 'was', 'born', 'and', 'raised', 'in', 'los', 'angeles', 'hollywood', 'to', 'be', 'exact', 'i', 'remember', 'growing', 'up', 'in', 'a', 'household', 'where', 'my', 'parents', 'enforced', 'the', 'spanish', 'language', 'but', 'my', 'sister', 'and', 'i', 'spoken', 'english', 'the', 'entire', 'time', 'at', 'school', 'so', 'you', 'see', 'how', 'my', 'brain', 'can', 'easily', 'mix', 'and', 'match', 'the', 'two', 'languages', 'mis', 'amigos', 'tease', 'me', 'because', 'i', 'pretty', 'much', 'speak', 'spanglish', 'most', 'of', 'the', 'time', 'so', 'im', 'glad', 'que', 'no', 'soy', 'la', 'unica', 'stay', 'tuned', 'for',
# ...

# %%
episode2 = ep2
words = nltk.word_tokenize(ep2)
words_ep2 =[word.lower() for word in words if word.isalpha()]
print(words_ep2)
# Out:
# ['alright', 'today', 'i', 'am', 'here', 'with', 'melissa', 'and', 'welcome', 'everybody', 'to', 'do', 'you', 'spanglish', 'todays', 'topic', 'is', 'the', 's', 'word', 'the', 's', 'word', 'whats', 'the', 's', 'word', 'cindy', 'are', 'we', 'talking', 'about', 'sex', 'what', 'exactly', 'are', 'we', 'talking', 'about', 'here', 'cuz', 'you', 'said', 'that', 'this', 'was', 'gunna', 'be', 'fun', 'and', 'not', 'embarrassing', 'spanish', 'okay', 'yay', 'el', 'español', 'basically', 'i', 'just', 'wan', 'na', 'talk', 'about', 'spanish', 'because', 'i', 'am', 'a', 'latino', 'who', 'was', 'born', 'and', 'raised', 'in', 'los', 'angeles', 'hollywood', 'literally', 'in', 'the', 'in', 'the', 'heart', 'of', 'hollywood', 'so', 'i', 'remember', 'growing', 'up', 'and', 'always', 'being', 'embarrassed', 'like', 'in', 'middle', 'school', 'and', 'even', 'in', 'high', 'school', 'being', 'embarrassed', 'of', 'just', 'speaking', 'spanish', 'around', 'my', 'friends', 'if', 'my', 'parents', 'came', 'around', 'an
# ...

# %%
episode3 = ep3
words = nltk.word_tokenize(ep3)
words_ep3 =[word.lower() for word in words if word.isalpha()]
print(words_ep3)
# Out:
# ['all', 'right', 'everyone', 'and', 'welcome', 'to', 'do', 'you', 'spanglish', 'today', 'i', 'have', 'my', 'friend', 'geneva', 'here', 'with', 'me', 'hi', 'thank', 'you', 'so', 'much', 'for', 'joining', 'me', 'thank', 'you', 'um', 'todays', 'topic', 'is', 'gunna', 'be', 'is', 'your', 'life', 'over', 'when', 'you', 'have', 'a', 'baby', 'uh', 'so', 'you', 'know', 'many', 'of', 'you', 'dont', 'know', 'my', 'friend', 'geneva', 'so', 'please', 'introduce', 'yourself', 'and', 'you', 'know', 'how', 'long', 'weve', 'known', 'each', 'other', 'and', 'tell', 'us', 'you', 'know', 'your', 'experience', 'as', 'a', 'mother', 'shes', 'a', 'mother', 'now', 'um', 'after', 'what', 'three', 'years', 'of', 'being', 'a', 'mother', 'so', 'i', 'just', 'want', 'to', 'kind', 'of', 'like', 'pick', 'your', 'brain', 'as', 'to', 'like', 'life', 'after', 'you', 'know', 'after', 'you', 'become', 'a', 'mother', 'yeah', 'okay', 'well', 'first', 'of', 'all', 'thank', 'you', 'for', 'having', 'me', 'of', 'course', 'supe
# ...
